# %%
# Importar librerías

# %%
import pandas as pd

# %%
import numpy as np

# %%
# Leer archivo csv

# %%
df = pd.read_csv('/content/netflix_titles.csv')

# %%
# Mostrar primeras filas

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# Tomar 5 registros

# %%
muestra = df[['title','release_year','type']].head(5)

# %%
muestra
# Out:
#                    title  release_year     type
# 0   Dick Johnson Is Dead          2020    Movie
# 1          Blood & Water          2021  TV Show
# 2              Ganglands          2021  TV Show
# 3  Jailbirds New Orleans          2021  TV Show
# 4           Kota Factory          2021  TV Show

# %%
# Convertir tipo a booleano

# %%
titulo1 = [
    muestra.iloc[0]['title'],
    int(muestra.iloc[0]['release_year']),
    muestra.iloc[0]['type'] == 'Movie'
]

# %%
titulo2 = [
    muestra.iloc[1]['title'],
    int(muestra.iloc[1]['release_year']),
    muestra.iloc[1]['type'] == 'Movie'
]

# %%
titulo3 = [
    muestra.iloc[2]['title'],
    int(muestra.iloc[2]['release_year']),
    muestra.iloc[2]['type'] == 'Movie'
]

# %%
titulo4 = [
    muestra.iloc[3]['title'],
    int(muestra.iloc[3]['release_year']),
    muestra.iloc[3]['type'] == 'Movie'
]

# %%
titulo5 = [
    muestra.iloc[4]['title'],
    int(muestra.iloc[4]['release_year']),
    muestra.iloc[4]['type'] == 'Movie'
]

# %%
print(titulo1)
print(titulo2)
print(titulo3)
print(titulo4)
print(titulo5)
# Out:
# ['Dick Johnson Is Dead', 2020, True]
# ['Blood & Water', 2021, False]
# ['Ganglands', 2021, False]
# ['Jailbirds New Orleans', 2021, False]
# ['Kota Factory', 2021, False]

# %%
# Catálogo provisional

# %%
catalogo_provisional = [
    titulo1,
    titulo2,
    titulo3,
    titulo4,
    titulo5
]

# %%
catalogo_provisional
# Out:
# [['Dick Johnson Is Dead', 2020, True],
#  ['Blood & Water', 2021, False],
#  ['Ganglands', 2021, False],
#  ['Jailbirds New Orleans', 2021, False],
#  ['Kota Factory', 2021, False]]

# %%
# Segundo y tercer título

# %%
sub_lista = catalogo_provisional[1:3]

# %%
sub_lista
# Out:
# [['Blood & Water', 2021, False], ['Ganglands', 2021, False]]

# %%
# Último título

# %%
print(catalogo_provisional[-1])
# Out:
# ['Kota Factory', 2021, False]

# %%
# Agregar un nuevo titulo

# %%
nuevo_titulo = [
    "Mi Pelicula Favorita",
    2026,
    True
]

# %%
catalogo_provisional.append(nuevo_titulo)

# %%
catalogo_provisional
# Out:
# [['Dick Johnson Is Dead', 2020, True],
#  ['Blood & Water', 2021, False],
#  ['Ganglands', 2021, False],
#  ['Jailbirds New Orleans', 2021, False],
#  ['Kota Factory', 2021, False],
#  ['Mi Pelicula Favorita', 2026, True]]

# %%
# Eliminar un titulo

# %%
catalogo_provisional.remove(titulo2)

# %%
catalogo_provisional
# Out:
# [['Dick Johnson Is Dead', 2020, True],
#  ['Ganglands', 2021, False],
#  ['Jailbirds New Orleans', 2021, False],
#  ['Kota Factory', 2021, False],
#  ['Mi Pelicula Favorita', 2026, True]]

# %%
# Tomar solo películas

# %%
peliculas = df[df['type'] == 'Movie']

# %%
peliculas[['title','duration']].head(10)
# Out:
#                                                 title duration
# 0                                Dick Johnson Is Dead   90 min
# 6                    My Little Pony: A New Generation   91 min
# 7                                             Sankofa  125 min
# 9                                        The Starling  104 min
# 12                                       Je Suis Karl  127 min
# 13                   Confessions of an Invisible Girl   91 min
# 16  Europe's Most Dangerous Man: Otto Skorzeny in ...   67 min
# 18                                          Intrusion   94 min
# 22                                    Avvai Shanmughi  161 min
# 23       Go! Go! Cory Carson: Chrissy Takes the Wheel   61 min

# %%
# Limpiar duración

# %%
duraciones = []

for d in peliculas['duration'].head(10):
    numero = int(d.replace(' min',''))
    duraciones.append(numero)

# %%
duraciones
# Out:
# [90, 91, 125, 104, 127, 91, 67, 94, 161, 61]

# %%
# Crear ndarray

# %%
duraciones_np = np.array(duraciones)

# %%
duraciones_np
# Out:
# array([ 90,  91, 125, 104, 127,  91,  67,  94, 161,  61])

# %%
# Buffer del 5%

# %%
buffer_5 = duraciones_np * 1.05

# %%
buffer_5
# Out:
# array([ 94.5 ,  95.55, 131.25, 109.2 , 133.35,  95.55,  70.35,  98.7 ,
#        169.05,  64.05])

# %%
# Duración ideal

# %%
duracion_ideal = np.array([100]*10)

# %%
duracion_ideal
# Out:
# array([100, 100, 100, 100, 100, 100, 100, 100, 100, 100])

# %%
# Desviación

# %%
desviacion = duraciones_np - duracion_ideal

# %%
desviacion
# Out:
# array([-10,  -9,  25,   4,  27,  -9, -33,  -6,  61, -39])

# %%
# Estadísticas

# %%
print("Promedio:", np.mean(duraciones_np))
print("Máximo:", np.max(duraciones_np))
print("Mínimo:", np.min(duraciones_np))
# Out:
# Promedio: 101.1
# Máximo: 161
# Mínimo: 61

# %%
# Crear lista_rrss

# %%
datos = df[
    ['show_id','type','title','release_year']
].head(10)

# %%
lista_rrss = datos.values.tolist()

# %%
lista_rrss
# Out:
# [['s1', 'Movie', 'Dick Johnson Is Dead', 2020],
#  ['s2', 'TV Show', 'Blood & Water', 2021],
#  ['s3', 'TV Show', 'Ganglands', 2021],
#  ['s4', 'TV Show', 'Jailbirds New Orleans', 2021],
#  ['s5', 'TV Show', 'Kota Factory', 2021],
#  ['s6', 'TV Show', 'Midnight Mass', 2021],
#  ['s7', 'Movie', 'My Little Pony: A New Generation', 2021],
#  ['s8', 'Movie', 'Sankofa', 1993],
#  ['s9', 'TV Show', 'The Great British Baking Show', 2021],
#  ['s10', 'Movie', 'The Starling', 2021]]

# %%
df_rrss = pd.DataFrame(
    lista_rrss,
    columns=[
        'ID',
        'Tipo',
        'Título',
        'Año'
    ]
)

# %%
df_rrss
# Out:
#     ID     Tipo                            Título   Año
# 0   s1    Movie              Dick Johnson Is Dead  2020
# 1   s2  TV Show                     Blood & Water  2021
# 2   s3  TV Show                         Ganglands  2021
# 3   s4  TV Show             Jailbirds New Orleans  2021
# 4   s5  TV Show                      Kota Factory  2021
# 5   s6  TV Show                     Midnight Mass  2021
# 6   s7    Movie  My Little Pony: A New Generation  2021
# 7   s8    Movie                           Sankofa  1993
# 8   s9  TV Show     The Great British Baking Show  2021
# 9  s10    Movie                      The Starling  2021

# %%
print("Cantidad de registros:", len(df_rrss))
# Out:
# Cantidad de registros: 10

# %%
df_rrss.head()
# Out:
#    ID     Tipo                 Título   Año
# 0  s1    Movie   Dick Johnson Is Dead  2020
# 1  s2  TV Show          Blood & Water  2021
# 2  s3  TV Show              Ganglands  2021
# 3  s4  TV Show  Jailbirds New Orleans  2021
# 4  s5  TV Show           Kota Factory  2021
