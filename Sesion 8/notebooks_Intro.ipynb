# %%
num1 = 5
num2 = 5
res = num1 + num1

# %%
print(f"La suma de {num1} y {num2} es {res}")
# Out:
# La suma de 5 y 5 es 10

# %%
a = float(input("Ingrese el valor de a: "))
b = float(input("Ingrese el valor de b: "))

resultado = (((a + b) / 5) ** 2) / 2

print("El resultado es:", resultado)
# Out:
# Ingrese el valor de a:  2.5443
# Ingrese el valor de b:  2.5443
# El resultado es: 0.5178769992

# %% [markdown]
# ![WhatsApp Image 2026-05-21 at 9.12.58 PM.jpeg](attachment:7bd11652-afdb-4d77-8de2-b343b5449d33.jpeg)

# %%
mango = 10
manzana = 5
aguacate = float (15)

# %%
resultado = (2 * aguacate) + (4 * manzana) + (1.5 * mango)

# %%
print("El resultado es:", resultado)
# Out:
# El resultado es: 65.0
