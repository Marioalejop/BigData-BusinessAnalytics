# %%
# Punto 1

# %%
ejemplo = {'nombre', 1548, True}

# %%
ejemplo
# Out:
# {1548, True, 'nombre'}

# %%
fbk = ['Facebook', 2449, True]
twt = ['Twitter', 339, False]
ig = ['Instagram', 1000, True]
yt = ['YouTube', 2000, False]
lkn = ['LinkedIn', 663, False]
wsp = ['WhatsApp', 1600, True]

# %%
#Punto 2

# %%
nombres_rsss = ['Facebook', 'Twitter', 'Instagram', 'YouTube', 'LinkedIn', 'WhatsApp']

# %%
nombres_rsss[0]
# Out:
# 'Facebook'

# %%
nombres_rsss[3]
# Out:
# 'YouTube'

# %%
nombres_rsss[0:3]
# Out:
# ['Facebook', 'Twitter', 'Instagram']

# %%
{nombres_rsss[1], nombres_rsss[3]}
# Out:
# {'Twitter', 'YouTube'}

# %%
nombres_rsss[2:5]
# Out:
# ['Instagram', 'YouTube', 'LinkedIn']

# %%
nombres_rsss[-4]
# Out:
# 'Instagram'

# %%
nombres_rsss[-2]
# Out:
# 'LinkedIn'

# %%
nombres_rsss.append('Tiktok')

# %%
fbk = ['Facebook', 2449, True]

# %%
fbk.append(2006)

# %%
fbk
# Out:
# ['Facebook', 2449, True, 2006]

# %%
twt.append(2006)

# %%
twt
# Out:
# ['Twitter', 339, False, 2006]

# %%
ig.append(2010)
yt.append(2005)
lkn.append(2003)
wsp.append(2009)

# %%
wsp
# Out:
# ['WhatsApp', 1600, True, 2009]

# %%
fbk.append('error')

# %%
fbk
# Out:
# ['Facebook', 2449, True, 2006, 'error']

# %%
fbk.remove('error')

# %%
fbk
# Out:
# ['Facebook', 2449, True, 2006]

# %%
nombres_rsss
# Out:
# ['Twitter', 'Instagram', 'YouTube', 'LinkedIn', 'WhatsApp', 'Tiktok', 'Tiktok']

# %%
nombres_rsss.remove('Tiktok')

# %%
nombres_rsss
# Out:
# ['Twitter', 'Instagram', 'YouTube', 'LinkedIn', 'WhatsApp', 'Tiktok']

# %%
nombres_rsss.append('Facebook')

# %%
nombres_rsss
# Out:
# ['Twitter',
#  'Instagram',
#  'YouTube',
#  'LinkedIn',
#  'WhatsApp',
#  'Tiktok',
#  'Facebook']

# %%
lista_rsss = [fbk, twt, ig, yt, lkn, wsp]

# %%
lista_rsss
# Out:
# [['Facebook', 2449, True, 2006],
#  ['Twitter', 339, False, 2006],
#  ['Instagram', 1000, True, 2010],
#  ['YouTube', 2000, False, 2005],
#  ['LinkedIn', 663, False, 2003],
#  ['WhatsApp', 1600, True, 2009]]
